# %% [markdown]
# <a href="https://colab.research.google.com/github/Ryanrc03/Chasing-the-Aha-Moment-/blob/main/nb/Llama3.1_(8B)_T4-GRPO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# To run this, press "*Runtime*" and press "*Run all*" on a **free** Tesla T4 Google Colab instance!
# <div class="align-center">
# <a href="https://unsloth.ai/"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
# <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord button.png" width="145"></a>
# <a href="https://docs.unsloth.ai/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a></a> Join Discord if you need help + ⭐ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐
# </div>
#
# To install Unsloth your local device, follow [our guide](https://docs.unsloth.ai/get-started/install-and-update). This notebook is licensed [LGPL-3.0](https://github.com/unslothai/notebooks?tab=LGPL-3.0-1-ov-file#readme).
#
# You will learn how to do [data prep](#Data), how to [train](#Train), how to [run the model](#Inference), & [how to save it](#Save)

# %% [markdown]
# ### News

# %% [markdown]
# Unsloth's [Docker image](https://hub.docker.com/r/unsloth/unsloth) is here! Start training with no setup & environment issues. [Read our Guide](https://docs.unsloth.ai/new/how-to-train-llms-with-unsloth-and-docker).
#
# [gpt-oss RL](https://docs.unsloth.ai/new/gpt-oss-reinforcement-learning) is now supported with the fastest inference & lowest VRAM. Try our [new notebook](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/gpt-oss-(20B)-GRPO.ipynb) which creates kernels!
#
# Introducing [Vision](https://docs.unsloth.ai/new/vision-reinforcement-learning-vlm-rl) and [Standby](https://docs.unsloth.ai/basics/memory-efficient-rl) for RL! Train Qwen, Gemma etc. VLMs with GSPO - even faster with less VRAM.
#
# Unsloth now supports Text-to-Speech (TTS) models. Read our [guide here](https://docs.unsloth.ai/basics/text-to-speech-tts-fine-tuning).
#
# Visit our docs for all our [model uploads](https://docs.unsloth.ai/get-started/all-our-models) and [notebooks](https://docs.unsloth.ai/get-started/unsloth-notebooks).

# %% [markdown]
# ### Installation

# %%
# %%capture
import os
os.environ["UNSLOTH_VLLM_STANDBY"] = "1" # [NEW] Extra 30% context lengths!
if "COLAB_" not in "".join(os.environ.keys()):
    # If you're not in Colab, just use pip install or uv pip install
    # !pip install unsloth vllm
else:
    pass # For Colab / Kaggle, we need extra instructions hidden below \/

# %%
#@title Colab Extra Install { display-mode: "form" }
# %%capture
import os
# !pip install --upgrade -qqq uv
if "COLAB_" not in "".join(os.environ.keys()):
    # If you're not in Colab, just use pip install!
    # !pip install unsloth vllm
else:
    try: import numpy, PIL; get_numpy = f"numpy=={numpy.__version__}"; get_pil = f"pillow=={PIL.__version__}"
    except: get_numpy = "numpy"; get_pil = "pillow"
    try: import subprocess; is_t4 = "Tesla T4" in str(subprocess.check_output(["nvidia-smi"]))
    except: is_t4 = False
    get_vllm, get_triton = ("vllm==0.9.2", "triton==3.2.0") if is_t4 else ("vllm==0.10.2", "triton")
    # !uv pip install -qqq --upgrade \
        unsloth {get_vllm} {get_numpy} {get_pil} torchvision bitsandbytes xformers
    # !uv pip install -qqq {get_triton}
# !uv pip install transformers==4.56.2
# !uv pip install --no-deps trl==0.22.2

# %% [markdown]
# ### Unsloth

# %% [markdown]
# Load up `Llama 3.1 8B Instruct`, and set parameters

# %%
from unsloth import FastLanguageModel
import torch
max_seq_length = 1024 # Can increase for longer reasoning traces
lora_rank = 32 # Larger rank = smarter, but slower

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/meta-Llama-3.1-8B-Instruct",
    max_seq_length = max_seq_length,
    load_in_4bit = True, # False for LoRA 16bit
    fast_inference = True, # Enable vLLM fast inference
    max_lora_rank = lora_rank,
    gpu_memory_utilization = 0.9, # Reduce if out of memory
)

model = FastLanguageModel.get_peft_model(
    model,
    r = lora_rank, # Choose any number > 0 ! Suggested 8, 16, 32, 64, 128
    target_modules = [
        "q_proj", "k_proj", "v_proj", "o_proj",
        "gate_proj", "up_proj", "down_proj",
    ], # Remove QKVO if out of memory
    lora_alpha = lora_rank,
    use_gradient_checkpointing = "unsloth", # Enable long context finetuning
    random_state = 3407,
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# INFO 10-21 20:31:42 [__init__.py:244] Automatically detected platform cuda.
# ERROR 10-21 20:31:45 [fa_utils.py:57] Cannot use FA version 2 is not supported due to FA2 is only supported on devices with compute capability >= 8
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# INFO 10-21 20:31:56 [vllm_utils.py:694] Unsloth: Patching vLLM v1 graph capture
# INFO 10-21 20:31:56 [vllm_utils.py:722] Unsloth: Patching vLLM v0 graph capture
# ==((====))==  Unsloth 2025.10.7: Fast Llama patching. Transformers: 4.56.2. vLLM: 0.9.2.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.7.0+cu126. CUDA: 7.5. CUDA Toolkit: 12.6. Triton: 3.2.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.30. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Unsloth: vLLM loading unsloth/meta-llama-3.1-8b-instruct-unsloth-bnb-4bit with actual GPU utilization = 89.15%
# Unsloth: Your GPU has CUDA compute capability 7.5 with VRAM = 14.74 GB.
# Unsloth: Using conservativeness = 1.0. Chunked prefill tokens = 1024. Num Sequences = 192.
# Unsloth: vLLM's KV Cache can use up to 6.97 GB. Also swap space = 0 GB.
# INFO 10-21 20:32:28 [config.py:841] This model supports multiple tasks: {'generate', 'reward', 'classify', 'embed'}. Defaulting to 'generate'.
# `torch_dtype` is deprecated! Use `dtype` instead!
# WARNING 10-21 20:32:28 [config.py:3371] Casting torch.bfloat16 to torch.float16.
# INFO 10-21 20:32:28 [config.py:1472] Using max model len 1024
# WARNING 10-21 20:32:28 [arg_utils.py:1735] Compute Capability < 8.0 is not supported by the V1 Engine. Falling back to V0.
# INFO 10-21 20:32:33 [config.py:2285] Chunked prefill is enabled with max_num_batched_tokens=2048.
# Unsloth: vLLM Bitsandbytes config using kwargs = {'load_in_8bit': False, 'load_in_4bit': True, 'bnb_4bit_compute_dtype': 'float16', 'bnb_4bit_quant_storage': 'uint8', 'bnb_4bit_quant_type': 'nf4', 'bnb_4bit_use_double_quant': True, 'llm_int8_enable_fp32_cpu_offload': False, 'llm_int8_has_fp16_weight': False, 'llm_int8_skip_modules': ['lm_head', 'multi_modal_projector', 'merger', 'modality_projection', 'model.layers.1.mlp'], 'llm_int8_threshold': 6.0}
# INFO 10-21 20:32:33 [llm_engine.py:230] Initializing a V0 LLM engine (v0.9.2) with config: model='unsloth/meta-llama-3.1-8b-instruct-unsloth-bnb-4bit', speculative_config=None, tokenizer='unsloth/meta-llama-3.1-8b-instruct-unsloth-bnb-4bit', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, override_neuron_config={}, tokenizer_revision=None, trust_remote_code=False, dtype=torch.float16, max_seq_len=1024, download_dir=None, load_format=LoadFormat.BITSANDBYTES, tensor_parallel_size=1, pipeline_parallel_size=1, disable_custom_all_reduce=False, quantization=bitsandbytes, enforce_eager=False, kv_cache_dtype=auto,  device_config=cuda, decoding_config=DecodingConfig(backend='auto', disable_fallback=False, disable_any_whitespace=False, disable_additional_properties=False, reasoning_backend=''), observability_config=ObservabilityConfig(show_hidden_metrics_for_version=None, otlp_traces_endpoint=None, collect_detailed_traces=None), seed=0, served_model_name=unsloth/meta-llama-3.1-8b-instruct-unsloth-bnb-4bit, num_scheduler_steps=1, multi_step_stream_outputs=True, enable_prefix_caching=True, chunked_prefill_enabled=True, use_async_output_proc=True, pooler_config=None, compilation_config={"level":0,"debug_dump_path":"","cache_dir":"","backend":"inductor","custom_ops":[],"splitting_ops":[],"use_inductor":true,"compile_sizes":[],"inductor_compile_config":{"epilogue_fusion":true,"max_autotune":false,"shape_padding":true,"trace.enabled":false,"triton.cudagraphs":true,"debug":false,"dce":true,"memory_planning":true,"coordinate_descent_tuning":false,"trace.graph_diagram":false,"compile_threads":4,"group_fusion":true,"disable_progress":false,"verbose_progress":true,"triton.multi_kernel":0,"triton.use_block_ptr":true,"triton.enable_persistent_tma_matmul":true,"triton.autotune_at_compile_time":false,"triton.cooperative_reductions":false,"cuda.compile_opt_level":"-O2","cuda.enable_cuda_lto":true,"combo_kernels":false,"benchmark_combo_kernel":true,"combo_kernel_foreach_dynamic_shapes":true,"enable_auto_functionalized_v2":false},"inductor_passes":{},"use_cudagraph":true,"cudagraph_num_of_warmups":1,"cudagraph_capture_sizes":[192,184,176,168,160,152,144,136,128,120,112,104,96,88,80,72,64,56,48,40,32,24,16,8,4,2,1],"cudagraph_copy_inputs":false,"full_cuda_graph":true,"max_capture_size":192,"local_cache_dir":null}, use_cached_outputs=False,
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.2M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/454 [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# INFO 10-21 20:32:39 [cuda.py:311] Cannot use FlashAttention-2 backend for Volta and Turing GPUs.
# INFO 10-21 20:32:39 [cuda.py:360] Using XFormers backend.
# INFO 10-21 20:32:40 [parallel_state.py:1076] rank 0 in world size 1 is assigned as DP rank 0, PP rank 0, TP rank 0, EP rank 0
# INFO 10-21 20:32:40 [model_runner.py:1171] Starting to load model unsloth/meta-llama-3.1-8b-instruct-unsloth-bnb-4bit...
# INFO 10-21 20:32:40 [bitsandbytes_loader.py:499] Loading weights with BitsAndBytes quantization. May take a while ...
# INFO 10-21 20:32:42 [weight_utils.py:292] Using model weights format ['*.safetensors']
# model.safetensors:   0%|          | 0.00/5.96G [00:00<?, ?B/s]
# INFO 10-21 20:33:33 [weight_utils.py:308] Time spent downloading weights for unsloth/meta-llama-3.1-8b-instruct-unsloth-bnb-4bit: 51.610837 seconds
# INFO 10-21 20:33:34 [weight_utils.py:345] No model.safetensors.index.json found in remote.
# Loading safetensors checkpoint shards:   0% Completed | 0/1 [00:00<?, ?it/s]
# Loading safetensors checkpoint shards:   0% Completed | 0/1 [00:00<?, ?it/s]
# INFO 10-21 20:33:57 [punica_selector.py:19] Using PunicaWrapperGPU.
# INFO 10-21 20:33:58 [model_runner.py:1203] Model loading took 5.7659 GiB and 76.940859 seconds
# INFO 10-21 20:34:10 [worker.py:294] Memory profiling takes 10.75 seconds
# INFO 10-21 20:34:10 [worker.py:294] the current vLLM instance can use total_gpu_memory (14.74GiB) x gpu_memory_utilization (0.89) = 13.14GiB
# INFO 10-21 20:34:10 [worker.py:294] model weights take 5.77GiB; non_torch_memory takes 0.03GiB; PyTorch activation peak memory takes 0.90GiB; the rest of the memory reserved for KV Cache is 6.45GiB.
# INFO 10-21 20:34:10 [executor_base.py:113] # cuda blocks: 3302, # CPU blocks: 0
# INFO 10-21 20:34:10 [executor_base.py:118] Maximum concurrency for 1024 tokens per request: 51.59x
# INFO 10-21 20:34:10 [vllm_utils.py:727] Unsloth: Running patched vLLM v0 `capture_model`.
# INFO 10-21 20:34:10 [model_runner.py:1513] Capturing cudagraphs for decoding. This may lead to unexpected consequences if the model is not static. To run the model in eager mode, set 'enforce_eager=True' or use '--enforce-eager' in the CLI. If out-of-memory error occurs during cudagraph capture, consider decreasing `gpu_memory_utilization` or switching to eager mode. You can also reduce the `max_num_seqs` as needed to decrease memory usage.
# Capturing CUDA graph shapes:   0%|          | 0/27 [00:00<?, ?it/s]
# INFO 10-21 20:34:37 [model_runner.py:1671] Graph capturing finished in 27 secs, took 0.59 GiB
# INFO 10-21 20:34:37 [vllm_utils.py:734] Unsloth: Patched vLLM v0 graph capture finished in 27 secs.
# INFO 10-21 20:34:38 [llm_engine.py:428] init engine (profile, create kv cache, warmup model) took 39.79 seconds
# Unsloth: Just some info: will skip parsing ['pre_feedforward_layernorm', 'ffn_norm', 'q_norm', 'post_layernorm', 'norm1', 'post_feedforward_layernorm', 'attention_norm', 'input_layernorm', 'layer_norm1', 'post_attention_layernorm', 'layer_norm2', 'norm2', 'k_norm']
# Unsloth: Just some info: will skip parsing ['pre_feedforward_layernorm', 'ffn_norm', 'cross_attn_post_attention_layernorm', 'q_norm', 'post_layernorm', 'cross_attn_input_layernorm', 'norm1', 'post_feedforward_layernorm', 'attention_norm', 'input_layernorm', 'layer_norm1', 'post_attention_layernorm', 'layer_norm2', 'norm2', 'k_norm']
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/454 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.2M [00:00<?, ?B/s]
# Unsloth 2025.10.7 patched 32 layers with 32 QKV layers, 32 O layers and 32 MLP layers.

# %% [markdown]
# ### Data Prep
# <a name="Data"></a>
#
# We directly leverage [@willccbb](https://gist.github.com/willccbb/4676755236bb08cab5f4e54a0475d6fb) for data prep and all reward functions. You are free to create your own!

# %%
import re
from datasets import load_dataset, Dataset

# Load and prep dataset
SYSTEM_PROMPT = """
Respond in the following format:
<reasoning>
...
</reasoning>
<answer>
...
</answer>
"""

XML_COT_FORMAT = """\
<reasoning>
{reasoning}
</reasoning>
<answer>
{answer}
</answer>
"""

def extract_xml_answer(text: str) -> str:
    answer = text.split("<answer>")[-1]
    answer = answer.split("</answer>")[0]
    return answer.strip()

def extract_hash_answer(text: str) -> str | None:
    if "####" not in text:
        return None
    return text.split("####")[1].strip()

# uncomment middle messages for 1-shot prompting
def get_gsm8k_questions(split = "train") -> Dataset:
    data = load_dataset('openai/gsm8k', 'main')[split] # type: ignore
    data = data.map(lambda x: { # type: ignore
        'prompt': [
            {'role': 'system', 'content': SYSTEM_PROMPT},
            {'role': 'user', 'content': x['question']}
        ],
        'answer': extract_hash_answer(x['answer'])
    }) # type: ignore
    return data # type: ignore

dataset = get_gsm8k_questions()

# Reward functions
def correctness_reward_func(prompts, completions, answer, **kwargs) -> list[float]:
    responses = [completion[0]['content'] for completion in completions]
    q = prompts[0][-1]['content']
    extracted_responses = [extract_xml_answer(r) for r in responses]
    print('-'*20, f"Question:\n{q}", f"\nAnswer:\n{answer[0]}", f"\nResponse:\n{responses[0]}", f"\nExtracted:\n{extracted_responses[0]}")
    return [2.0 if r == a else 0.0 for r, a in zip(extracted_responses, answer)]

def int_reward_func(completions, **kwargs) -> list[float]:
    responses = [completion[0]['content'] for completion in completions]
    extracted_responses = [extract_xml_answer(r) for r in responses]
    return [0.5 if r.isdigit() else 0.0 for r in extracted_responses]

def strict_format_reward_func(completions, **kwargs) -> list[float]:
    """Reward function that checks if the completion has a specific format."""
    pattern = r"^<reasoning>\n.*?\n</reasoning>\n<answer>\n.*?\n</answer>\n$"
    responses = [completion[0]["content"] for completion in completions]
    matches = [re.match(pattern, r) for r in responses]
    return [0.5 if match else 0.0 for match in matches]

def soft_format_reward_func(completions, **kwargs) -> list[float]:
    """Reward function that checks if the completion has a specific format."""
    pattern = r"<reasoning>.*?</reasoning>\s*<answer>.*?</answer>"
    responses = [completion[0]["content"] for completion in completions]
    matches = [re.match(pattern, r) for r in responses]
    return [0.5 if match else 0.0 for match in matches]

def count_xml(text) -> float:
    count = 0.0
    if text.count("<reasoning>\n") == 1:
        count += 0.125
    if text.count("\n</reasoning>\n") == 1:
        count += 0.125
    if text.count("\n<answer>\n") == 1:
        count += 0.125
        count -= len(text.split("\n</answer>\n")[-1])*0.001
    if text.count("\n</answer>") == 1:
        count += 0.125
        count -= (len(text.split("\n</answer>")[-1]) - 1)*0.001
    return count

def xmlcount_reward_func(completions, **kwargs) -> list[float]:
    contents = [completion[0]["content"] for completion in completions]
    return [count_xml(c) for c in contents]
# Out:
# README.md: 0.00B [00:00, ?B/s]
# main/train-00000-of-00001.parquet:   0%|          | 0.00/2.31M [00:00<?, ?B/s]
# main/test-00000-of-00001.parquet:   0%|          | 0.00/419k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/7473 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/1319 [00:00<?, ? examples/s]
# Map:   0%|          | 0/7473 [00:00<?, ? examples/s]

# %% [markdown]
# <a name="Train"></a>
# ### Train the model
#
# Now set up GRPO Trainer and all configurations!

# %%
max_prompt_length = 256

from trl import GRPOConfig, GRPOTrainer
training_args = GRPOConfig(
    learning_rate = 5e-6,
    adam_beta1 = 0.9,
    adam_beta2 = 0.99,
    weight_decay = 0.1,
    warmup_ratio = 0.1,
    lr_scheduler_type = "cosine",
    optim = "paged_adamw_8bit",
    logging_steps = 1,
    per_device_train_batch_size = 1,
    gradient_accumulation_steps = 1, # Increase to 4 for smoother training
    num_generations = 6, # Decrease if out of memory
    max_prompt_length = max_prompt_length,
    max_completion_length = max_seq_length - max_prompt_length,
    # num_train_epochs = 1, # Set to 1 for a full training run
    max_steps = 250, # Reduced for faster testing
    save_steps = 250,
    max_grad_norm = 0.1,
    report_to = "none", # Can use Weights & Biases
    output_dir = "outputs",
)
# Out:
# Unsloth: We now expect `per_device_train_batch_size` to be a multiple of `num_generations`.
# We will change the batch size of 1 to the `num_generations` of 6

# %% [markdown]
# And let's run the trainer! If you scroll up, you'll see a table of rewards. The goal is to see the `reward` column increase!
#
# You might have to wait 150 to 200 steps for any action. You'll probably get 0 reward for the first 100 steps. Please be patient!
#
# | Step | Training Loss | reward    | reward_std | completion_length | kl       |
# |------|---------------|-----------|------------|-------------------|----------|
# | 1    | 0.000000      | 0.125000  | 0.000000   | 200.000000        | 0.000000 |
# | 2    | 0.000000      | 0.072375  | 0.248112   | 200.000000        | 0.000000 |
# | 3    | 0.000000      | -0.079000 | 0.163776   | 182.500000        | 0.000005 |

# %%
trainer = GRPOTrainer(
    model = model,
    processing_class = tokenizer,
    reward_funcs = [
        xmlcount_reward_func,
        soft_format_reward_func,
        strict_format_reward_func,
        int_reward_func,
        correctness_reward_func,
    ],
    args = training_args,
    train_dataset = dataset,
)
trainer.train()
# Out:
# The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'pad_token_id': 128004}.
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 7,473 | Num Epochs = 1 | Total steps = 250
# O^O/ \_/ \    Batch size per device = 6 | Gradient accumulation steps = 1
# \        /    Data Parallel GPUs = 1 | Total batch size (6 x 1 x 1) = 6
#  "-____-"     Trainable parameters = 83,886,080 of 8,114,147,328 (1.03% trained)
# -------------------- Question:
# A concert ticket costs $40. Mr. Benson bought 12 tickets and received a 5% discount for every ticket bought that exceeds 10. How much did Mr. Benson pay in all?
# Answer:
# 476
# Response:
# Let's break down the problem:
#
# 1. The first 10 tickets will be priced at the full price of $40.
# 2. The remaining 2 tickets (12 - 10 = 2) qualify for a 5% discount.
#
# First, calculate the cost of the first 10 tickets:
# 10 tickets * $40 = $400
#
# For the 2 tickets with the discount, calculate the discount:
# 2 tickets * 5% = 2 * $40 * 5% = 2 * $40 * 0.05 = $4 per ticket
#
# So, the discounted price for each of the 2 tickets is:
# $40 - $4 = $36 per ticket
#
# Now, calculate the cost of the 2 discounted tickets:
# 2 tickets * $36 = $72
#
# Now, add the cost of the discounted tickets to the cost of the first 10 tickets:
# $400 + $72 = $472
#
# <answer> $472
# Extracted:
# $472
#     <div>
#
#       <progress value='26' max='250' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 26/250 19:20 < 3:00:35, 0.02 it/s, Epoch 0.00/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>reward</th>
#       <th>reward_std</th>
#       <th>completions / mean_length</th>
#       <th>completions / min_length</th>
#       <th>completions / max_length</th>
#       <th>completions / clipped_ratio</th>
#       <th>completions / mean_terminated_length</th>
#       <th>completions / min_terminated_length</th>
#       <th>completions / max_terminated_length</th>
#       <th>kl</th>
#       <th>rewards / xmlcount_reward_func / mean</th>
#       <th>rewards / xmlcount_reward_func / std</th>
#       <th>rewards / soft_format_reward_func / mean</th>
#       <th>rewards / soft_format_reward_func / std</th>
#       <th>rewards / strict_format_reward_func / mean</th>
#       <th>rewards / strict_format_reward_func / std</th>
#       <th>rewards / int_reward_func / mean</th>
#       <th>rewards / int_reward_func / std</th>
#       <th>rewards / correctness_reward_func / mean</th>
#       <th>rewards / correctness_reward_func / std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>-0.000000</td>
#       <td>0.327833</td>
#       <td>1.085287</td>
#       <td>193.833344</td>
#       <td>157.000000</td>
#       <td>232.000000</td>
#       <td>0.000000</td>
#       <td>193.833344</td>
#       <td>157.000000</td>
#       <td>232.000000</td>
#       <td>0.000000</td>
#       <td>-0.088833</td>
#       <td>0.217596</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.083333</td>
#       <td>0.204124</td>
#       <td>0.333333</td>
#       <td>0.816497</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>313.000000</td>
#       <td>214.000000</td>
#       <td>432.000000</td>
#       <td>0.000000</td>
#       <td>313.000000</td>
#       <td>214.000000</td>
#       <td>432.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.000000</td>
#       <td>-0.121833</td>
#       <td>0.192096</td>
#       <td>186.666672</td>
#       <td>117.000000</td>
#       <td>229.000000</td>
#       <td>0.000000</td>
#       <td>186.666672</td>
#       <td>117.000000</td>
#       <td>229.000000</td>
#       <td>0.000005</td>
#       <td>-0.121833</td>
#       <td>0.192096</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.000000</td>
#       <td>0.975333</td>
#       <td>1.082343</td>
#       <td>209.666672</td>
#       <td>145.000000</td>
#       <td>288.000000</td>
#       <td>0.000000</td>
#       <td>209.666672</td>
#       <td>145.000000</td>
#       <td>288.000000</td>
#       <td>0.000005</td>
#       <td>-0.274667</td>
#       <td>0.347084</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.250000</td>
#       <td>0.273861</td>
#       <td>1.000000</td>
#       <td>1.095445</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>-0.000000</td>
#       <td>0.413500</td>
#       <td>0.957425</td>
#       <td>127.666672</td>
#       <td>103.000000</td>
#       <td>182.000000</td>
#       <td>0.000000</td>
#       <td>127.666672</td>
#       <td>103.000000</td>
#       <td>182.000000</td>
#       <td>0.000017</td>
#       <td>-0.003167</td>
#       <td>0.082633</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.083333</td>
#       <td>0.204124</td>
#       <td>0.333333</td>
#       <td>0.816497</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.000000</td>
#       <td>1.095834</td>
#       <td>1.219604</td>
#       <td>230.333344</td>
#       <td>158.000000</td>
#       <td>346.000000</td>
#       <td>0.000000</td>
#       <td>230.333344</td>
#       <td>158.000000</td>
#       <td>346.000000</td>
#       <td>0.000005</td>
#       <td>-0.154167</td>
#       <td>0.273742</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.250000</td>
#       <td>0.273861</td>
#       <td>1.000000</td>
#       <td>1.095445</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.000000</td>
#       <td>0.404333</td>
#       <td>0.930985</td>
#       <td>230.333344</td>
#       <td>190.000000</td>
#       <td>293.000000</td>
#       <td>0.000000</td>
#       <td>230.333344</td>
#       <td>190.000000</td>
#       <td>293.000000</td>
#       <td>0.000006</td>
#       <td>-0.012333</td>
#       <td>0.103602</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.083333</td>
#       <td>0.204124</td>
#       <td>0.333333</td>
#       <td>0.816497</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.000000</td>
#       <td>0.416667</td>
#       <td>1.020621</td>
#       <td>100.166672</td>
#       <td>76.000000</td>
#       <td>148.000000</td>
#       <td>0.000000</td>
#       <td>100.166672</td>
#       <td>76.000000</td>
#       <td>148.000000</td>
#       <td>0.000010</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.083333</td>
#       <td>0.204124</td>
#       <td>0.333333</td>
#       <td>0.816497</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>165.166672</td>
#       <td>156.000000</td>
#       <td>190.000000</td>
#       <td>0.000000</td>
#       <td>165.166672</td>
#       <td>156.000000</td>
#       <td>190.000000</td>
#       <td>0.000008</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.000000</td>
#       <td>0.104333</td>
#       <td>0.200281</td>
#       <td>205.500000</td>
#       <td>142.000000</td>
#       <td>262.000000</td>
#       <td>0.000000</td>
#       <td>205.500000</td>
#       <td>142.000000</td>
#       <td>262.000000</td>
#       <td>0.000006</td>
#       <td>0.021000</td>
#       <td>0.051439</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.083333</td>
#       <td>0.204124</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.000000</td>
#       <td>-0.073000</td>
#       <td>0.178813</td>
#       <td>157.833344</td>
#       <td>121.000000</td>
#       <td>216.000000</td>
#       <td>0.000000</td>
#       <td>157.833344</td>
#       <td>121.000000</td>
#       <td>216.000000</td>
#       <td>0.000010</td>
#       <td>-0.073000</td>
#       <td>0.178813</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.000000</td>
#       <td>-0.026167</td>
#       <td>0.064095</td>
#       <td>188.666672</td>
#       <td>138.000000</td>
#       <td>281.000000</td>
#       <td>0.000000</td>
#       <td>188.666672</td>
#       <td>138.000000</td>
#       <td>281.000000</td>
#       <td>0.000006</td>
#       <td>-0.026167</td>
#       <td>0.064095</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>-0.000000</td>
#       <td>0.833333</td>
#       <td
# Unsloth: Will smartly offload gradients to save VRAM!
# -------------------- Question:
# Jane is trying to decide whether to buy a house or a trailer. A house costs $480,000 and a trailer costs $120,000. Each loan will be paid in monthly installments over 20 years. How much more is the monthly payment on the house compared to the trailer?
# Answer:
# 1500
# Response:
# To find the monthly payment difference, we need to find the monthly payment for each option and then subtract the trailer payment from the house payment.
#
# The formula for monthly payment is M = P[r(1+r)^n]/[(1+r)^n - r], where P is the principal (initial cost), r is the monthly interest rate, and n is the number of payments (months).
#
# However, we don't know the interest rate. If we assume the interest rate is the same for both the house and the trailer, the interest rate difference would be the same regardless of the loan amount, which means it would cancel out when subtracting the payments.
#
# Instead we can use another method, the ratio of the two loans. Assuming a fixed interest rate, the monthly payment is proportional to the principal and the number of months.
#
# For the trailer:   $120,000 / 20 * 12
#                   = $720
# For the house:    $480,000 / 20 * 12
#                   = $2880
#
# $2880 - $720
# $2160
# Extracted:
# To find the monthly payment difference, we need to find the monthly payment for each option and then subtract the trailer payment from the house payment.
#
# The formula for monthly payment is M = P[r(1+r)^n]/[(1+r)^n - r], where P is the principal (initial cost), r is the monthly interest rate, and n is the number of payments (months).
#
# However, we don't know the interest rate. If we assume the interest rate is the same for both the house and the trailer, the interest rate difference would be the same regardless of the loan amount, which means it would cancel out when subtracting the payments.
#
# Instead we can use another method, the ratio of the two loans. Assuming a fixed interest rate, the monthly payment is proportional to the principal and the number of months.
#
# For the trailer:   $120,000 / 20 * 12
#                   = $720
# For the house:    $480,000 / 20 * 12
#                   = $2880
#
# $2880 - $720
# $2160
# -------------------- Question:
# Janet pays $40/hour for 3 hours per week of clarinet lessons and $28/hour for 5 hours a week of piano lessons. How much more does she spend on piano lessons than clarinet lessons in a year?
# Answer:
# 1040
# Response:
# First, let's calculate how much Janet spends on clarinet lessons and piano lessons per week.
# Clarinet lessons weekly cost: $40/hour * 3 hours = $120/week
# Piano lessons weekly cost: $28/hour * 5 hours = $140/week
# To find out how much more she spends on piano lessons than clarinet lessons per week, we need to subtract the weekly cost of the clarinet lessons from the weekly cost of the piano lessons.
# Difference in a week: $140/week - $120/week = $20/week
# To find out how much more she spends on piano lessons than clarinet lessons in a year, we multiply the weekly difference by the number of weeks in a year. There are 52 weeks in a year.
# Difference in a year: $20/week * 52 weeks/year = $1040/year
# <answer> $1040.
# Extracted:
# $1040.
# -------------------- Question:
# Sabrina is collecting herbs to make a poultice for her grandmother. She needs twice as many basil leaves as sage leaves and 5 fewer sage leaves than verbena leaves. If she needs 12 basil leaves, how many leaves total does she need?
# Answer:
# 29
# Response:
# To find the number of sage leaves Sabrina needs, divide the number of basil leaves by 2.
#
# Since she needs twice as many basil leaves as sage leaves and she has 12 basil leaves, she must have half of 12 basil leaves, which is 12 / 2 = 6 sage leaves.
#
# To find the number of verbena leaves, note that she needs 5 fewer sage leaves than verbena leaves. So the verbena leaves will be sage leaves plus 5, which is 6 + 5 = 11.
#
# The total number of leaves she needs is the sum of basil, sage, and verbena leaves: 12 + 6 + 11 = 29.
#
# <answer> 29.
# Extracted:
# 29.
# -------------------- Question:
# Over the past five years, on July 4th, the high temperature for Washington, DC has been: 90 degrees in 2020, 90 degrees in 2019, 90 degrees in 2018, 79 degrees in 2017 and 71 degrees in 2016. What is the average temperature for July 4th in Washington, DC over the past 5 years?
# Answer:
# 84
# Response:
# To calculate the average temperature, you must add all the temperatures and divide by the number of years.
#
# First, add all the temperatures:
# 90 + 90 + 90 + 79 + 71 = 320.
#
# There are 5 years.
#
# Now, add the total (320) divided by the number of years (5):
# 320 / 5 = 64.
#
# The average temperature for July 4th in Washington, DC over the past 5 years is 64 degrees.
# Extracted:
# To calculate the average temperature, you must add all the temperatures and divide by the number of years.
#
# First, add all the temperatures:
# 90 + 90 + 90 + 79 + 71 = 320.
#
# There are 5 years.
#
# Now, add the total (320) divided by the number of years (5):
# 320 / 5 = 64.
#
# The average temperature for July 4th in Washington, DC over the past 5 years is 64 degrees.
# -------------------- Question:
# Rene can finish reading 30 pages in 60 minutes. Lulu can read 27 pages in 60 minutes and Cherry can read 25 pages in 60 minutes. If they have been reading for 240 minutes now, how many pages have they finished reading in total?
# Answer:
# 328
# Response:
# To find the total pages read, we need to find how many pages each of them read in 240 minutes and then add them up.
#
# First, let's find Rene's reading rate in 240 minutes.
# Since Rene can read 30 pages in 60 minutes, we multiply 30 by the number of 60-minute blocks in 240 minutes. 240 divided by 60 is 4. So, Rene's total pages read = 30 * 4 = 120.
#
# Next, let's find Lulu's reading rate in 240 minutes.
# Since Lulu can read 27 pages in 60 minutes, we multiply 27 by the number of 60-minute blocks in 240 minutes. 240 divided by 60 is 4. So, Lulu's total pages read = 27 * 4 = 108.
#
# Finally, let's find Cherry's reading rate in 240 minutes.
# Since Cherry can read 25 pages in 60 minutes, we multiply 25 by the number of 60-minute blocks in 240 minutes. 240 divided by 60 is 4. So, Cherry's total pages read = 25 * 4 = 100.
#
# Total pages read by all = Rene's pages + Lulu's pages + Cherry's pages = 120 + 108 + 100 = 328.
#
# <reasoning>
# To find the reading time and total pages in 240 minutes we used the formula: time * rate = result. So, if a person can read "x" number of pages in 60 minutes, in "y" number of minutes they can read x*y pages.
# </reasoning>
# <answer>
# 328
# </answer>
# Extracted:
# 328
# -------------------- Question:
# Martin rings the small bell 4 times more than 1/3 as often as the big bell. If he rings both of them a combined total of 52 times, how many times does he ring the big bell?
# Answer:
# 36
# Response:
# Let's break this down step by step.
#
# Let the number of times Martin rings the big bell be B, and the number of times he rings the small bell be S.
#
# We know that Martin rings the small bell 4 times more than 1/3 as often as the big bell. So, the number of times he rings the small bell is B + 4, which is 1/3 of the big bell.
#
# We can write this as an equation:
#
# S = B + 4 = (1/3)B
#
# We can solve this by multiplying both sides by 3 to get:
#
# 3S = 3B + 12
#
# We also know that the total number of rings is 52, which means the sum of the big bell rings and the small bell rings is 52.
#
# We can write this as another equation:
#
# B + S = 52
#
# Now, we can substitute the expression for S (B + 4) into this equation:
#
# B + (B + 4) = 52
#
# Combine like terms:
#
# 2B + 4 = 52
#
# Subtract 4 from both sides:
#
# 2B = 48
#
# Divide by 2:
#
# B = 24
#
# The big bell is rung 24 times.
#
# The small bell is rung 24 + 4 = 28 times.
#
# So, the big bell is rung 24 times.
# </answer>24
# Extracted:
# Let's break this down step by step.
#
# Let the number of times Martin rings the big bell be B, and the number of times he rings the small bell be S.
#
# We know that Martin rings the small bell 4 times more than 1/3 as often as the big bell. So, the number of times he rings the small bell is B + 4, which is 1/3 of the big bell.
#
# We can write this as an equation:
#
# S = B + 4 = (1/3)B
#
# We can solve this by multiplying both sides by 3 to get:
#
# 3S = 3B + 12
#
# We also know that the total number of rings is 52, which means the sum of the big bell rings and the small bell rings is 52.
#
# We can write this as another equation:
#
# B + S = 52
#
# Now, we can substitute the expression for S (B + 4) into this equation:
#
# B + (B + 4) = 52
#
# Combine like terms:
#
# 2B + 4 = 52
#
# Subtract 4 from both sides:
#
# 2B = 48
#
# Divide by 2:
#
# B = 24
#
# The big bell is rung 24 times.
#
# The small bell is rung 24 + 4 = 28 times.
#
# So, the big bell is rung 24 times.
# -------------------- Question:
# Bert fills out the daily crossword puzzle in the newspaper every day. He uses up a pencil to fill out the puzzles every two weeks. On average, it takes him 1050 words to use up a pencil. How many words are in each crossword puzzle on average?
# Answer:
# 75
# Response:
# Let's break this down. Since Bert uses up a pencil every two weeks, and there are approximately 7 days in a week, he uses up a pencil in 2 * 7 = 14 days.
#
# Since it takes him 1050 words to use up a pencil, we need to divide 1050 by 14 to get the average number of words he does each day.
#
# 1050 / 14 = 75
#
# So, on average, each crossword puzzle contains 75 words.
# Extracted:
# Let's break this down. Since Bert uses up a pencil every two weeks, and there are approximately 7 days in a week, he uses up a pencil in 2 * 7 = 14 days.
#
# Since it takes him 1050 words to use up a pencil, we need to divide 1050 by 14 to get the average number of words he does each day.
#
# 1050 / 14 = 75
#
# So, on average, each crossword puzzle contains 75 words.
# -------------------- Question:
# Matt can make a batch of a dozen cookies using 2 pounds of flour.  He uses 4 bags of flour each weighing 5 pounds.  If Jim eats 15 cookies how many cookies are left?
# Answer:
# 105
# Response:
# Let's break down the information given:
#
# - Matt needs 2 pounds of flour to make a batch of a dozen cookies.
# - Matt has 4 bags of flour, each weighing 5 pounds.
# - Therefore, Matt has a total of 4 * 5 = 20 pounds of flour.
#
# Since Matt uses 2 pounds of flour per batch, he can make 20 / 2 = 10 batches.
#
# Each batch makes 12 cookies, so in total, Matt can make 10 batches * 12 cookies per batch = 120 cookies.
#
# However, Jim eats 15 cookies. To find the number of cookies left, we need to subtract 15 from the total number of cookies Matt can make:
#
# 120 - 15 = 105
#
# So, there are 105 cookies left.
# Extracted:
# Let's break down the information given:
#
# - Matt needs 2 pounds of flour to make a batch of a dozen cookies.
# - Matt has 4 bags of flour, each weighing 5 pounds.
# - Therefore, Matt has a total of 4 * 5 = 20 pounds of flour.
#
# Since Matt uses 2 pounds of flour per batch, he can make 20 / 2 = 10 batches.
#
# Each batch makes 12 cookies, so in total, Matt can make 10 batches * 12 cookies per batch = 120 cookies.
#
# However, Jim eats 15 cookies. To find the number of cookies left, we need to subtract 15 from the total number of cookies Matt can make:
#
# 120 - 15 = 105
#
# So, there are 105 cookies left.
# -------------------- Question:
# James decides to build a tin house by collecting 500 tins in a week. On the first day, he collects 50 tins. On the second day, he manages to collect 3 times that number. On the third day, he collects 50 tins fewer than the number he collected on the second day. If he collects an equal number of tins on the remaining days of the week, what's the number of tins he collected each day for the rest of the week?
# Answer:
# 50
# Response:
# If he collects 50 tins on the first day,
# on the second day, he collects 50 * 3 = 150 tins.
# On the third day, he collects 150 - 50 = 100 tins.
#
# We need to calculate the remaining number of tins he collected after the first three days.
# 50 + 150 + 100 = 300 tins.
#
# He has left 500 - 300 = 200 tins to collect for the rest of the week.
# There are 4 remaining days in the week (from the 4th day to the 7th day).
# 200 tins / 4 days = 50 tins per day.
# Extracted:
# If he collects 50 tins on the first day,
# on the second day, he collects 50 * 3 = 150 tins.
# On the third day, he collects 150 - 50 = 100 tins.
#
# We need to calculate the remaining number of tins he collected after the first three days.
# 50 + 150 + 100 = 300 tins.
#
# He has left 500 - 300 = 200 tins to collect for the rest of the week.
# There are 4 remaining days in the week (from the 4th day to the 7th day).
# 200 tins / 4 days = 50 tins per day.
# -------------------- Question:
# A jar of jellybeans has 14 blue jellybeans, 26 purple jellybeans and 40 orange jellybeans. If there are 200 jellybeans in the jar, how many are there of the red color?
# Answer:
# 120
# Response:
# lü calculation of the total number of blue, purple and orange jellybeans in the jar is 14 + 26 + 40 = 80.
#
# Since the total number of jellybeans in the jar is 200 and we already calculated that 80 are blue, purple or orange, the number of jellybeans that are either red or another color is 200 - 80 = 120.
#
# Since there is only one other color mentioned, red, and 80 jellybeans are blue, purple or orange, there must be 120 - 80 = 40 red jellybeans in the jar.
# Extracted:
# lü calculation of the total number of blue, purple and orange jellybeans in the jar is 14 + 26 + 40 = 80.
#
# Since the total number of jellybeans in the jar is 200 and we already calculated that 80 are blue, purple or orange, the number of jellybeans that are either red or another color is 200 - 80 = 120.
#
# Since there is only one other color mentioned, red, and 80 jellybeans are blue, purple or orange, there must be 120 - 80 = 40 red jellybeans in the jar.
# -------------------- Question:
# Five adults and two children go to see a movie and buy $12 worth of concessions. The total cost of their trip is $76. If each child's ticket is $7, how much, in dollars, are the adult tickets?
# Answer:
# 10
# Response:
# Let's denote the price of an adult ticket as "A". The price of each child's ticket is $7, and there are two children.
#
# The total cost of two children's tickets is 2 * $7 = $14.
#
# The total cost of five adult tickets is 5 * $A.
#
# Their total cost of the trip is $76. Since we know the total bill for concessions and tickets, and the bill for concessions was $12, the remaining $76 - $12 = $64 is for tickets.
#
# So we can set up an equation to solve for A:
#
# $14 (children's tickets) + 5A (adult tickets) = $64 (total tickets cost)
#
# Subtract $14 from both sides:
# 5A = $64 - $14
# 5A = $50
#
# Now, divide both sides by 5:
# A = $50 / 5
# A = $10
#
# The price of each adult ticket is $10.
# Extracted:
# Let's denote the price of an adult ticket as "A". The price of each child's ticket is $7, and there are two children.
#
# The total cost of two children's tickets is 2 * $7 = $14.
#
# The total cost of five adult tickets is 5 * $A.
#
# Their total cost of the trip is $76. Since we know the total bill for concessions and tickets, and the bill for concessions was $12, the remaining $76 - $12 = $64 is for tickets.
#
# So we can set up an equation to solve for A:
#
# $14 (children's tickets) + 5A (adult tickets) = $64 (total tickets cost)
#
# Subtract $14 from both sides:
# 5A = $64 - $14
# 5A = $50
#
# Now, divide both sides by 5:
# A = $50 / 5
# A = $10
#
# The price of each adult ticket is $10.
# -------------------- Question:
# Janelle had 26 green marbles. Then she bought 6 bags of blue marbles. There were 10 marbles in each bag.  She created a gift of 6 green marbles and 8 blue marbles and gave it to a friend. How many marbles does Janelle have now?
# Answer:
# 72
# Response:
# First, let's figure out how many blue marbles Janelle bought. Since she bought 6 bags of blue marbles and each bag had 10 marbles, she bought 6 * 10 = 60 blue marbles.
#
# Janelle had 26 green marbles initially. After creating a gift of 6 green marbles, she had 26 - 6 = 20 green marbles left.
#
# For the blue marbles, she bought 60 and gave away 8 in the gift. So, she has 60 - 8 = 52 blue marbles left.
#
# To find out how many marbles Janelle has now, we need to add the remaining green and blue marbles: 20 + 52 = 72.
#
# So, Janelle has 72 marbles now.
# Extracted:
# First, let's figure out how many blue marbles Janelle bought. Since she bought 6 bags of blue marbles and each bag had 10 marbles, she bought 6 * 10 = 60 blue marbles.
#
# Janelle had 26 green marbles initially. After creating a gift of 6 green marbles, she had 26 - 6 = 20 green marbles left.
#
# For the blue marbles, she bought 60 and gave away 8 in the gift. So, she has 60 - 8 = 52 blue marbles left.
#
# To find out how many marbles Janelle has now, we need to add the remaining green and blue marbles: 20 + 52 = 72.
#
# So, Janelle has 72 marbles now.
# -------------------- Question:
# Every day in a week, Siena bookmarks 30 website pages from the research she does on her browser. If Siena has 400 bookmarked pages on her bookmarks library now, how many pages will she have in her bookmarks library at the end of March?
# Answer:
# 1330
# Response:
# Assuming every day is a working day for Siena, she has 31 days in a month of March. Since she bookmarks 30 pages each day, at the end of March she will have
#
# 30 * 31 = 930 bookmarks in total.
# Since Siena already has 400 bookmarked pages, she will have a total of:
#
# 930 + 400 = 1330 bookmarked pages at the end of March.
# Extracted:
# Assuming every day is a working day for Siena, she has 31 days in a month of March. Since she bookmarks 30 pages each day, at the end of March she will have
#
# 30 * 31 = 930 bookmarks in total.
# Since Siena already has 400 bookmarked pages, she will have a total of:
#
# 930 + 400 = 1330 bookmarked pages at the end of March.
# -------------------- Question:
# An old pirate wants to leave his treasure on an island. He has 3500 gold coins. He wants to spread this equally across 5 chests. Additionally, he will put a total of 500 silver coins and twice as many bronze coins as silver, all distributed equally across the chests. How many coins in total will be in each chest?
# Answer:
# 1000
# Response:
# There are 3 types of coins: gold, silver, and bronze.
#
# The pirate has 3500 gold coins, which will be divided by 5 chests. Therefore, chests will have 3500/5 = 700 gold coins.
#
# He has 500 silver coins, which will be divided by 5 chests. Therefore, chests will have 500/5 = 100 silver coins.
#
# He will put twice as many bronzen coins as silver coins. So the number of bronzen coins is 500 * 2 = 1000. Therefore, the bronze coins will be divided by 5 chests. So, the number in each chest is 1000/5 = 200.
#
# To find the total number of coins in each chest, we will add the coins of type. 700 (gold coins) + 100 (silver coins) + 200 (bronze coins) = 1000.
# Extracted:
# There are 3 types of coins: gold, silver, and bronze.
#
# The pirate has 3500 gold coins, which will be divided by 5 chests. Therefore, chests will have 3500/5 = 700 gold coins.
#
# He has 500 silver coins, which will be divided by 5 chests. Therefore, chests will have 500/5 = 100 silver coins.
#
# He will put twice as many bronzen coins as silver coins. So the number of bronzen coins is 500 * 2 = 1000. Therefore, the bronze coins will be divided by 5 chests. So, the number in each chest is 1000/5 = 200.
#
# To find the total number of coins in each chest, we will add the coins of type. 700 (gold coins) + 100 (silver coins) + 200 (bronze coins) = 1000.
# -------------------- Question:
# Ephraim has two machines that make necklaces for his store. On Sunday the first machine made 45 necklaces. The second machine made 2.4 times as many necklaces as the first machine. How many necklaces were made in total on Sunday?
# Answer:
# 153
# Response:
# </reasoning> To find the total number of necklaces made on Sunday, we need to first find out how many necklaces the second machine made and then add that to the number made by the first machine.
#
# </reasoning>
# The first machine made 45 necklaces. The second machine made 2.4 times as many necklaces as the first machine, so the second machine made 45 * 2.4 = 108 necklaces. To find the total number of necklaces made on Sunday, we add the necklaces made by both machines: 45 + 108 = 153.
#
# </answer>
# Extracted:
# </reasoning> To find the total number of necklaces made on Sunday, we need to first find out how many necklaces the second machine made and then add that to the number made by the first machine.
#
# </reasoning>
# The first machine made 45 necklaces. The second machine made 2.4 times as many necklaces as the first machine, so the second machine made 45 * 2.4 = 108 necklaces. To find the total number of necklaces made on Sunday, we add the necklaces made by both machines: 45 + 108 = 153.
# -------------------- Question:
# Zach baked cookies for a bake sale. On Monday he baked 32 cookies. On Tuesday he ran out of sugar and could only bake half of the number of cookies he baked the day before. On Wednesday he baked three times the number of cookies he did on Tuesday, but his brother ate 4 of those cookies. How many cookies did he have at the end of the three days?
# Answer:
# 92
# Response:
# Let's break down the information:
#
# On Monday, Zach baked 32 cookies.
# On Tuesday, he baked half of the number he baked on Monday, which is 32 / 2 = 16 cookies.
# On Wednesday, he baked three times the number of cookies he did on Tuesday, which is 3 * 16 = 48 cookies. However, his brother ate 4 of those cookies, leaving him with 48 - 4 = 44 cookies.
#
# To find the total number of cookies at the end of the three days, we need to add the cookies from each day:
#
# 32 (Monday) + 16 (Tuesday) + 44 (Wednesday) = 92 cookies.
#
# Therefore, the total number of cookies Zach had at the end of the three days is 92.
# Extracted:
# Let's break down the information:
#
# On Monday, Zach baked 32 cookies.
# On Tuesday, he baked half of the number he baked on Monday, which is 32 / 2 = 16 cookies.
# On Wednesday, he baked three times the number of cookies he did on Tuesday, which is 3 * 16 = 48 cookies. However, his brother ate 4 of those cookies, leaving him with 48 - 4 = 44 cookies.
#
# To find the total number of cookies at the end of the three days, we need to add the cookies from each day:
#
# 32 (Monday) + 16 (Tuesday) + 44 (Wednesday) = 92 cookies.
#
# Therefore, the total number of cookies Zach had at the end of the three days is 92.
# -------------------- Question:
# Mark and James need a total of 14 dice that are 12 sided to play their game.  Mark has a bag of 10 dice and 60% of them are 12 sided.  James has a bag of 8 dice and 75% of them are 12 sided.  How many dice will the boys need to buy to play their game?
# Answer:
# 2
# Response:
# To find out how many dice the boys need to buy, we first need to find out how many 12-sided dice each of them has.
#
# Mark has a bag of 10 dice, and 60% of them are 12-sided.
# To find out how many 12-sided dice Mark has, we need to multiply 10 by 60%.
# 10 * 0.6 = 6
# So Mark has 6 twelve-sided dice.
#
# James has a bag of 8 dice, and 75% of them are 12-sided.
# To find out how many 12-sided dice James has, we need to multiply 8 by 75%.
# 8 * 0.75 = 6
# So James has 6 twelve-sided dice.
#
# The boys need a total of 14 dice for their game. They have a total of 6 + 6 = 12 dice.
#
# To find the number of dice they need to buy, we need to subtract 12 from 14.
# 14 - 12 = 2
# So the boys need to buy 2 more dice.
# Extracted:
# To find out how many dice the boys need to buy, we first need to find out how many 12-sided dice each of them has.
#
# Mark has a bag of 10 dice, and 60% of them are 12-sided.
# To find out how many 12-sided dice Mark has, we need to multiply 10 by 60%.
# 10 * 0.6 = 6
# So Mark has 6 twelve-sided dice.
#
# James has a bag of 8 dice, and 75% of them are 12-sided.
# To find out how many 12-sided dice James has, we need to multiply 8 by 75%.
# 8 * 0.75 = 6
# So James has 6 twelve-sided dice.
#
# The boys need a total of 14 dice for their game. They have a total of 6 + 6 = 12 dice.
#
# To find the number of dice they need to buy, we need to subtract 12 from 14.
# 14 - 12 = 2
# So the boys need to buy 2 more dice.
# -------------------- Question:
# Erin counts six trolls hiding by the path in the forest, 6 less than four times that number of trolls hiding under the bridge, and half as many trolls hiding in the plains as under the bridge. How many trolls did she count in total?
# Answer:
# 33
# Response:
# Let's break this down step by step:
#
# If Erin counts six trolls hiding by the path in the forest, let's call the number of trolls hiding by the path 'a' which equals to 6.
#
# The problem says four times that number of trolls are hiding under the bridge, so the number of trolls hiding under the bridge is (4 * 6) - 6, which is 24 - 6 = 18.
#
# Now, the problem states that the number of trolls hiding in the plains is half as many as under the bridge. So, the number of trolls hiding in the plains is (18 / 2) = 9.
#
# To find the total number of trolls, add the trolls by the forest path, under the bridge, and in the plains. Therefore, the total number of trolls Erin counted is 6 + 18 + 9 = 33.
#
# <reasoning>
# 1. Define variables representing the number of trolls in each location.
# 2. Convert words to mathematical expressions for easier solving.
# 3. Solve each location's expression.
# 4. Perform final addition with all solved values.
#
# </reasoning>
# <answer>
# 33
#
# </answer>
# Extracted:
# 33
# -------------------- Question:
# Karen packs peanut butter sandwiches in her daughter's lunch 2 randomly chosen days of the week. The other 3 school days, she packs a ham sandwich. She packs a piece of cake on one randomly chosen day and cookies the other four days. What is the probability, expressed as a percentage, that Karen packs a ham sandwich and cake on the same day?
# Answer:
# 12
# Response:
# There are 5 school days. Since the days are randomly chosen, we can consider this as an arranging of items problem where repetition is allowed (packing ham on two days and cake on one day can be thought of as two spots either scooped or given or 33322 as non sequential and can be reversed).
#
# The total number of days is 5 and the ham sandwich gets used 3 days and cake 1 day so there's 3C1 * 1C1 = 3 ways to pick your ham and cake combination.
#
# Total combinations of packing lunches = 5!. There are three arrangements of ham on 3 chosen days chosen by combination which also need to be multiplied by the combination of 5 choose three to consider all five cases. So that equals 3!*(3 choose 3)=3!. Favorable or wins is 3.
#
# The probability is (3/5!) * 100 = (3/120) * 100 = 2.5%
#
# So the final answer is <The number of ways Karen packs a ham sandwich and cake on the same day is 3 out of a total of 5!. The probability is (3/5!) * 100 or 2.5%.
# </The number of ways Karen packs a ham sandwich and cake on the same day is 3 out of a total of 5!. The probability is (3/5!) * 100 or 2.5%>
#
# <answer>
# 2.5%
# </answer>
# Extracted:
# 2.5%
# -------------------- Question:
# A four-layer pyramid is being built with each layer having three times as many sandstone blocks as the layer above it. The top layer is a single block. How many sandstone blocks are in the pyramid?
# Answer:
# 40
# Response:
# Let's think about this problem.
#
# Since the top layer has one block, the second layer will have three times that amount: 3 blocks.  The third layer will have three times that amount: 3 * 3 = 9 blocks.  The fourth layer will have three times that amount: 3 * 9 = 27 blocks.
#
# To find out the total number of blocks we add them all up: 1 + 3 + 9 + 27 = 40
#
# <answer>40</answer>
# Extracted:
# 40
# -------------------- Question:
# The cost of Joe's new HVAC system is $20,000.  It includes 2 conditioning zones, each with 5 vents.  In dollars, what is the cost of the system per vent?
# Answer:
# 2,000
# Response:
# <break the problem down into smaller parts>
# The problem is asking for the cost of the system per vent.  There are two conditioning zones and each zone has 5 vents.  So, there are a total of 2 x 5 = 10 vents.
#
# <find the total cost of the system>
# The total cost of the system is $20,000.
#
# <calculate the cost per vent>
# To find the cost of the system per vent, we need to divide the total cost of the system by the total number of vents.
# Cost per vent = total cost / total vents = $20,000 / 10 vents
#
# <perform the calculation>
# $20,000 / 10 vents = $2,000 per vent
#
# <answer>
# The cost of the system per vent is $2,000.
# Extracted:
# The cost of the system per vent is $2,000.
# -------------------- Question:
# Trent walked 4 blocks from his house to the bus stop. He rode the bus 7 blocks to the library. Later, he came home the same way. How many blocks did Trent travel in all?
# Answer:
# 22
# Response:
# There is information that Trent traveled to the library and then came back home the same way. This means he traveled to the library and back.
#
# He walked 4 blocks to the bus stop, rode the bus 7 blocks to the library, which makes 4 + 7 = 11 blocks to the library.
# Since he then came back the same way, he again traveled 11 blocks to return to his house.
#
# So, the total distance he traveled is 11 (to the library) + 11 (back home) = 22 blocks.
#
# Therefore, Trent traveled a total of 22 blocks.
#
# </answer>
# Extracted:
# There is information that Trent traveled to the library and then came back home the same way. This means he traveled to the library and back.
#
# He walked 4 blocks to the bus stop, rode the bus 7 blocks to the library, which makes 4 + 7 = 11 blocks to the library.
# Since he then came back the same way, he again traveled 11 blocks to return to his house.
#
# So, the total distance he traveled is 11 (to the library) + 11 (back home) = 22 blocks.
#
# Therefore, Trent traveled a total of 22 blocks.
# -------------------- Question:
# Lee had $10 and his friend had $8. They went to a restaurant where they ordered chicken wings for $6 and a chicken salad for $4. They also got 2 sodas for $1.00 each. The tax came to $3. How much change should they have received in total?
# Answer:
# 3
# Response:
# <mathematically break down the cost>
# - Chicken wings: $6
# - Chicken salad: $4
# - Sodas (2 x $1): $2
# Total cost before tax: $6 + $4 + $2 = $12
# - Adding tax: $12 + $3 = $15
# </mathematically break down the cost>
# Since they had a total of $10 + $8 = $18, they had enough money to cover the cost. To find out how much change they should receive, we subtract the total cost from their total money.
# $18 - $15 = $3
#
# <answer>
# $3
# Extracted:
# $3
# -------------------- Question:
# Andy walks 50 meters from his house to school. After school, he comes back to the house and goes to the market. If he walks 140 meters in total, how many meters is the distance between the house and the market?
# Answer:
# 40
# Response:
# reasoning
# We know that Andy walks a total of 140 meters.  First, he walks his house to school which is 50 meters. Then he also walks back to his house which is the same 50 meters. So he doesn't need to travel 50 x 2 = 100 meters again, no, he only needs to cover the distance between the house to the market which is x. So, we have an equation:
# 50 + x + 50 = 140.
# The 50 in the equation is for the walk from the house to school and the 50 again for the walk back from the school to the house.
# Extracted:
# reasoning
# We know that Andy walks a total of 140 meters.  First, he walks his house to school which is 50 meters. Then he also walks back to his house which is the same 50 meters. So he doesn't need to travel 50 x 2 = 100 meters again, no, he only needs to cover the distance between the house to the market which is x. So, we have an equation:
# 50 + x + 50 = 140.
# The 50 in the equation is for the walk from the house to school and the 50 again for the walk back from the school to the house.

# %% [markdown]
# <a name="Inference"></a>
# ### Inference
# Now let's try the model we just trained! First, let's first try the model without any GRPO trained:

# %%
text = tokenizer.apply_chat_template([
    {"role" : "user", "content" : "Calculate pi."},
], tokenize = False, add_generation_prompt = True)

from vllm import SamplingParams
sampling_params = SamplingParams(
    temperature = 0.8,
    top_p = 0.95,
    max_tokens = 1024,
)
output = model.fast_generate(
    [text],
    sampling_params = sampling_params,
    lora_request = None,
)[0].outputs[0].text

output

# %% [markdown]
# And now with the LoRA we just trained with GRPO - we first save the LoRA first!

# %%
model.save_lora("grpo_saved_lora")

# %% [markdown]
# Now we load the LoRA and test:

# %%
text = tokenizer.apply_chat_template([
    {"role" : "system", "content" : SYSTEM_PROMPT},
    {"role" : "user", "content" : "Calculate pi."},
], tokenize = False, add_generation_prompt = True)

from vllm import SamplingParams
sampling_params = SamplingParams(
    temperature = 0.8,
    top_p = 0.95,
    max_tokens = 1024,
)
output = model.fast_generate(
    text,
    sampling_params = sampling_params,
    lora_request = model.load_lora("grpo_saved_lora"),
)[0].outputs[0].text

output

# %% [markdown]
# Our reasoning model is much better - it's not always correct, since we only trained it for an hour or so - it'll be better if we extend the sequence length and train for longer!

# %% [markdown]
# <a name="Save"></a>
# ### Saving to float16 for VLLM
#
# We also support saving to `float16` directly. Select `merged_16bit` for float16 or `merged_4bit` for int4. We also allow `lora` adapters as a fallback. Use `push_to_hub_merged` to upload to your Hugging Face account! You can go to https://huggingface.co/settings/tokens for your personal tokens.

# %%
# Merge to 16bit
if False: model.save_pretrained_merged("model", tokenizer, save_method = "merged_16bit",)
if False: model.push_to_hub_merged("hf/model", tokenizer, save_method = "merged_16bit", token = "")

# Merge to 4bit
if False: model.save_pretrained_merged("model", tokenizer, save_method = "merged_4bit",)
if False: model.push_to_hub_merged("hf/model", tokenizer, save_method = "merged_4bit", token = "")

# Just LoRA adapters
if False:
    model.save_pretrained("model")
    tokenizer.save_pretrained("model")
if False:
    model.push_to_hub("hf/model", token = "")
    tokenizer.push_to_hub("hf/model", token = "")

# %% [markdown]
# ### GGUF / llama.cpp Conversion
# To save to `GGUF` / `llama.cpp`, we support it natively now! We clone `llama.cpp` and we default save it to `q8_0`. We allow all methods like `q4_k_m`. Use `save_pretrained_gguf` for local saving and `push_to_hub_gguf` for uploading to HF.
#
# Some supported quant methods (full list on our [Wiki page](https://github.com/unslothai/unsloth/wiki#gguf-quantization-options)):
# * `q8_0` - Fast conversion. High resource use, but generally acceptable.
# * `q4_k_m` - Recommended. Uses Q6_K for half of the attention.wv and feed_forward.w2 tensors, else Q4_K.
# * `q5_k_m` - Recommended. Uses Q6_K for half of the attention.wv and feed_forward.w2 tensors, else Q5_K.
#
# [**NEW**] To finetune and auto export to Ollama, try our [Ollama notebook](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3_(8B)-Ollama.ipynb)

# %%
# Save to 8bit Q8_0
if False: model.save_pretrained_gguf("model", tokenizer,)
# Remember to go to https://huggingface.co/settings/tokens for a token!
# And change hf to your username!
if False: model.push_to_hub_gguf("hf/model", tokenizer, token = "")

# Save to 16bit GGUF
if False: model.save_pretrained_gguf("model", tokenizer, quantization_method = "f16")
if False: model.push_to_hub_gguf("hf/model", tokenizer, quantization_method = "f16", token = "")

# Save to q4_k_m GGUF
if False: model.save_pretrained_gguf("model", tokenizer, quantization_method = "q4_k_m")
if False: model.push_to_hub_gguf("hf/model", tokenizer, quantization_method = "q4_k_m", token = "")

# Save to multiple GGUF options - much faster if you want multiple!
if False:
    model.push_to_hub_gguf(
        "hf/model", # Change hf to your username!
        tokenizer,
        quantization_method = ["q4_k_m", "q8_0", "q5_k_m",],
        token = "",
    )

# %% [markdown]
# Now, use the `model-unsloth.gguf` file or `model-unsloth-Q4_K_M.gguf` file in llama.cpp.
#
# And we're done! If you have any questions on Unsloth, we have a [Discord](https://discord.gg/unsloth) channel! If you find any bugs or want to keep updated with the latest LLM stuff, or need help, join projects etc, feel free to join our Discord!
#
# Some other links:
# 1. Train your own reasoning model - Llama GRPO notebook [Free Colab](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3.1_(8B)-GRPO.ipynb)
# 2. Saving finetunes to Ollama. [Free notebook](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3_(8B)-Ollama.ipynb)
# 3. Llama 3.2 Vision finetuning - Radiography use case. [Free Colab](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3.2_(11B)-Vision.ipynb)
# 6. See notebooks for DPO, ORPO, Continued pretraining, conversational finetuning and more on our [documentation](https://docs.unsloth.ai/get-started/unsloth-notebooks)!
#
# <div class="align-center">
#   <a href="https://unsloth.ai"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
#   <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord.png" width="145"></a>
#   <a href="https://docs.unsloth.ai/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a>
#
#   Join Discord if you need help + ⭐️ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐️
# </div>
# Now, use the `model-unsloth.gguf` file or `model-unsloth-Q4_K_M.gguf` file in llama.cpp.
#
# And we're done! If you have any questions on Unsloth, we have a [Discord](https://discord.gg/unsloth) channel! If you find any bugs or want to keep updated with the latest LLM stuff, or need help, join projects etc, feel free to join our Discord!
#
# Some other links:
# 1. Train your own reasoning model - Llama GRPO notebook [Free Colab](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3.1_(8B)-GRPO.ipynb)
# 2. Saving finetunes to Ollama. [Free notebook](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3_(8B)-Ollama.ipynb)
# 3. Llama 3.2 Vision finetuning - Radiography use case. [Free Colab](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3.2_(11B)-Vision.ipynb)
# 6. See notebooks for DPO, ORPO, Continued pretraining, conversational finetuning and more on our [documentation](https://docs.unsloth.ai/get-started/unsloth-notebooks)!
#
# <div class="align-center">
#   <a href="https://unsloth.ai"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
#   <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord.png" width="145"></a>
#   <a href="https://docs.unsloth.ai/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a>
#
#   Join Discord if you need help + ⭐️ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐️
#
#   This notebook and all Unsloth notebooks are licensed [LGPL-3.0](https://github.com/unslothai/notebooks?tab=LGPL-3.0-1-ov-file#readme).
# </div>
